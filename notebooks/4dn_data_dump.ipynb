# %%
import pandas as pd

# %%
# fpath = "/nfs/turbo/umms-indikar/shared/projects/twin_cell/data/human/sc_hic/4DN/metadata_2024-11-19-14h-48m.tsv"
fpath = "/nfs/turbo/umms-indikar/shared/projects/twin_cell/data/human/sc_hic/4DN/metadata_2024-11-21-09h-14m.tsv"

df = pd.read_csv(fpath, sep='\t', comment="#")
print(df.columns)
df.head()
# Out:
# Index(['File Download URL', 'Experiment Set Accession', 'Experiment Accession',
#        'File Accession', 'Size (MB)', 'md5sum', 'File Type', 'File Format',
#        'Bio Rep No', 'Tech Rep No', 'Biosource Type', 'Organism',
#        'Related File Relationship', 'Related File', 'Paired End', 'Set Status',
#        'File Status', 'Publication', 'Experiment Type', 'Replicate Info',
#        'Assay Details', 'Biosource', 'Dataset', 'Condition',
#        'In Experiment As', 'Project', 'Generating Lab', 'Experimental Lab',
#        'Contributing Lab', 'Notes', 'Open Data URL'],
#       dtype='object')
#                                    File Download URL Experiment Set Accession  \
# 0  https://data.4dnucleome.org/files-fastq/4DNFI2...             4DNES1BK1RMQ
# 1  https://data.4dnucleome.org/files-fastq/4DNFI4...             4DNES1BK1RMQ
# 2  https://data.4dnucleome.org/files-fastq/4DNFIN...             4DNES1BK1RMQ
# ...

# %%
df['Experiment Set Accession'].nunique()
# Out:
# 8

# %%
# keep_columns = [
#     'Size (MB)', 
#     'File Type',
#     'File Format',
#     'Bio Rep No', 
#     'Tech Rep No', 
#     'Biosource Type', 
#     'Organism',
#     'File Status', 
#     'Publication', 
#     'Experiment Type',
#     'Replicate Info',
#     'Assay Details', 
#     'Biosource',
#     'Dataset',
#     'Condition',
#     'In Experiment As', 
#     'Project', 
#     'Notes', 
# ]

# df[keep_columns].to_csv("4DN_metadata.csv")

# %%
df['Biosource Type'].value_counts()
# Out:
# Biosource Type
# induced pluripotent stem cell    385
# immortalized cell line            24
# stem cell derived cell line       17
# primary cell line                  5
# Name: count, dtype: int64

# %%
df['Biosource'].value_counts()
# Out:
# Biosource
# WTC-11 AAVS1-GFP C28     188
# WTC-11 AAVS1-GFP C6      188
# multiple                  32
# WTC-11 with MYL2-EGFP      8
# H1-hESC (Tier 1)           8
# Name: count, dtype: int64
