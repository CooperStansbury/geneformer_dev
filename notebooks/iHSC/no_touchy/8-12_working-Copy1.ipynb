# %% [markdown]
# # 8-9 Centroids and Distance Calculations

# %% [markdown]
# #### Diverged from the 8/2 copy on 8/9, for no particular reason or bug, just to date properly, reorganize with more comments and less plot drafts, and save more backups.  At this point I also saved a copy in no_touchy. I will replace that one with a newer version as it comes.

# %%
import sys
import seaborn as sns
import pandas as pd 
import numpy as np
from itertools import combinations
from scipy.spatial.distance import squareform, pdist
from scipy.spatial.distance import cdist
import matplotlib.pyplot as plt
import torch
import anndata as ad
import scanpy as sc
import os
import gc
from importlib import reload
print("C1")

from datasets import Dataset, load_from_disk
from datasets import load_dataset
from geneformer import EmbExtractor

from sklearn.cluster import KMeans
print("C2")

#classifer tools
import xgboost
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import confusion_matrix
print("C3")

sns.set_style('white')
torch.cuda.empty_cache()

import os

from datasets import Dataset, load_from_disk, load_dataset
import geneformer

from datetime import datetime
print("C4")
DEFAULT_NAME_PATH = "/nfs/turbo/umms-indikar/shared/projects/geneformer/geneformer/gene_name_id_dict.pkl"
DEFAULT_TOKEN_PATH = "/nfs/turbo/umms-indikar/shared/projects/geneformer/token_dictionary.pkl"
DEFAULT_MEDIAN_PATH = "/nfs/turbo/umms-indikar/shared/projects/geneformer/geneformer/gene_median_dictionary.pkl"

sns.set_style('white')
torch.cuda.empty_cache()
print("C5")
# Out:
# C1
# C2
# C3
# C4
# C5

# %%
import scipy
print(f"Scipy version: {scipy.__version__}")
# Out:
# Scipy version: 1.14.0

# %% [markdown]
# # Load in the Single Cell Data

# %% [markdown]
# ## In Silico Perturbed

# %% [markdown]
# #### This loads in all the perturbed cells from turbo, which already have k means cluster columns in obs and look nice

# %%
import anndata as ad
reprog_wid_path = '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/' + 'nat_reprog_centroid_adata_all_2'
reprog_centroid_adata_wid = ad.read_h5ad(reprog_wid_path)
# this is not actually written into the file idk if we care? 
reprog_centroid_adata_wid.obs['type'] = 'reprogrammed'
reprog_centroid_adata_wid.obs['cluster_number'] = range(1, len(reprog_centroid_adata_wid.obs) + 1)

reprog_centroid_adata_wid.obs.size
# Out:
# /home/oliven/miniconda3/envs/geneformer2/lib/python3.10/site-packages/anndata/_core/aligned_df.py:67: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# 15120

# %%
"""
Sometimes the same set of cell_ids shows up duplicated in the list, but if 
it does, there is always a differenct recipe 
Identify the perturbation uniquely by (recipe_number, kmeans_cluster)
"""
# Out:
# '\nSometimes the same set of cell_ids shows up duplicated in the list, but if \nit does, there is always a differenct recipe \nIdentify the perturbation uniquely by (recipe_number, kmeans_cluster)\n'

# %%
unique_cell_ids = reprog_centroid_adata_wid.obs['cell_id'].nunique()
print(unique_cell_ids)
print(reprog_centroid_adata_wid.shape)
# Out:
# 2509
# (2520, 512)

# %%
non_unique_cell_ids = reprog_centroid_adata_wid.obs[reprog_centroid_adata_wid.obs.duplicated('cell_id', keep=False)]
truly_non_unique_cell_ids = non_unique_cell_ids[non_unique_cell_ids.duplicated('recipe_name', keep=False)]

# Sort the rows by 'cell_id'
sorted_non_unique_cell_ids = truly_non_unique_cell_ids.sort_values(by='cell_id')

sorted_non_unique_cell_ids.head(20)

# # Display the sorted rows with column headers and proper formatting
# print(sorted_non_unique_cell_ids.to_string(index=False))
# Out:
# Empty DataFrame
# Columns: [kmeans_cluster, recipe_name, recipe_number, cell_id, type, cluster_number]
# Index: []

# %% [markdown]
# ## Initial Fibroblast

# %% [markdown]
# #### Rather than loading in the unperturbed cells, we don't really have them neatly saved to a nice place, except for in some of those files from the slurm job that had them tacked at the top.  Make a separate df of those, from any one of the files that had them.

# %%
# Just pick from a random file where they were copied (the first half ish of them have them still in original). Then filter by type

harvest_file_path = '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/originals/2024-07-31_03-49-01_job_number_22.h5ad'
harvest_file_adata = ad.read_h5ad(harvest_file_path)
initial_adata = harvest_file_adata[harvest_file_adata.obs['type'] == 'initial']

initial_adata.obs.sample(10)
# Out:
# /home/oliven/miniconda3/envs/geneformer2/lib/python3.10/site-packages/anndata/_core/aligned_df.py:67: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
#                                        input_ids       cell_type  \
# 11244  [ 5357 17626 10769 ...  2992  9398  4536]  Myofibroblasts
# 14494  [16916 10769  5902 ... 18489 17063 11549]     Fibroblasts
# 9818   [ 5716   454 10769 ...  5900  3891   386]  Myofibroblasts
# 15089  [16916  9009   454 ... 13643  2554  4734]     Fibroblasts
# 6199   [16916 16166 16876 ...  4151   663  3920]     Fibroblasts
# 5602   [ 3878 15960 16166 ...  3196 13852  2162]      fibroblast
# 3595   [ 1732 16916  3878 ... 15348  8142  3229]      fibroblast
# 8743   [16916 16876 19437 ...   825  3023 19926]     Fibroblasts
# 439    [16916  3878 16876 ...  7689  3589 17785]      fibroblast
# 11168  [ 3878   376  9009 ... 21001 20499 10887]     Fibroblasts
#
#               dataset length          ignore standardized_cell_type  \
# 11244          TS_Fat   2048  Myofibroblasts             Fibroblast
# 14494          TS_Fat   2048     Fibroblasts             Fibroblast
# 9818           TS_Fat   2048  Myofibroblasts             Fibroblast
# 15089          TS_Fat   2048     Fibroblasts             Fibroblast
# 6199           TS_Fat   2048     Fibroblasts             Fibroblast
# 5602   TS_Vasculature   2048      fibroblast             Fibroblast
# 3595   TS_Vasculature   2048      fibroblast             Fibroblast
# 8743           TS_Fat   2048     Fibroblasts             Fibroblast
# 439    TS_Vasculature   2048      fibroblast             Fibroblast
# 11168          TS_Fat   1913     Fibroblasts             Fibroblast
#
#        broad_type __index_level_0__     cell_id recipe     type
# 11244  fibroblast            163198  cell_11245    raw  initial
# 14494  fibroblast            170178  cell_14495    raw  initial
# 9818   fibroblast            160183   cell_9819    raw  initial
# 15089  fibroblast            171475  cell_15090    raw  initial
# 6199   fibroblast            152404   cell_6200    raw  initial
# 5602   fibroblast            125110   cell_5603    raw  initial
# 3595   fibroblast            119591   cell_3596    raw  initial
# 8743   fibroblast            157884   cell_8744    raw  initial
# 439    fibroblast            111001    cell_440    raw  initial
# 11168  fibroblast            163007  cell_11169    raw  initial

# %%
# get adata up and working
# Ensure hsc_adata is already defined and populated with data

# 1. Check the contents of the original obs
print("Original obs contents:")
print(initial_adata.obs.head())

# 2. Create the backup
initial_adata.uns['obs_backup'] = initial_adata.obs.copy()

# 3. Verify the backup was created correctly
print("Contents of obs_backup after creation:")
print(initial_adata.uns['obs_backup'].head())

# 4. Clear the original obs
initial_adata.obs = pd.DataFrame(index=initial_adata.obs.index)

# 5. Check the contents of the cleared obs and the backup
print("Contents of cleared obs:")
print(initial_adata.obs.head())

print("Contents of obs_backup after clearing original obs:")
print(initial_adata.uns['obs_backup'].head())
# Out:
# Original obs contents:
#                                    input_ids   cell_type         dataset  \
# 0  [16345  9009 13048 ...  9332 13451  5456]  fibroblast  TS_Vasculature
# 1  [12119  9190 16876 ... 11232  1132  1022]  fibroblast  TS_Vasculature
# 2  [ 3878  9009  4115 ...  4697 10362 12098]  fibroblast  TS_Vasculature
# 3  [ 3878 16916 18367 ... 15470  3946  2153]  fibroblast  TS_Vasculature
# 4  [ 6196 16916 10920 ...  7629 10148 17125]  fibroblast  TS_Vasculature
#
#   length      ignore standardized_cell_type  broad_type __index_level_0__  \
# 0   2048  fibroblast             Fibroblast  fibroblast            109770
# 1   2048  fibroblast             Fibroblast  fibroblast            109771
# 2   2048  fibroblast             Fibroblast  fibroblast            109774
# 3   2048  fibroblast             Fibroblast  fibroblast            109776
# 4   2048  fibroblast             Fibroblast  fibroblast            109777
#
#   cell_id recipe     type
# 0  cell_1    raw  initial
# 1  cell_2    raw  initial
# 2  cell_3    raw  initial
# 3  cell_4    raw  initial
# 4  cell_5    raw  initial
# Contents of obs_backup after creation:
#                                    input_ids   cell_type         dataset  \
# 0  [16345  9009 13048 ...  9332 13451  5456]  fibroblast  TS_Vasculature
# 1  [12119  9190 16876 ... 11232  1132  1022]  fibroblast  TS_Vasculature
# 2  [ 3878  9009  4115 ...  4697 10362 12098]  fibroblast  TS_Vasculature
# 3  [ 3878 16916 18367 ... 15470  3946  2153]  fibroblast  TS_Vasculature
# 4  [ 6196 16916 10920 ...  7629 10148 17125]  fibroblast  TS_Vasculature
#
#   length      ignore standardized_cell_type  broad_type __index_level_0__  \
# 0   2048  fibroblast             Fibroblast  fibroblast            109770
# 1   2048  fibroblast             Fibroblast  fibroblast            109771
# 2   2048  fibroblast             Fibroblast  fibroblast            109774
# 3   2048  fibroblast             Fibroblast  fibroblast            109776
# 4   2048  fibroblast             Fibroblast  fibroblast            109777
#
#   cell_id recipe     type
# 0  cell_1    raw  initial
# 1  cell_2    raw  initial
# 2  cell_3    raw  initial
# 3  cell_4    raw  initial
# 4  cell_5    raw  initial
# Contents of cleared obs:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]
# Contents of obs_backup after clearing original obs:
#                                    input_ids   cell_type         dataset  \
# 0  [16345  9009 13048 ...  9332 13451  5456]  fibroblast  TS_Vasculature
# 1  [12119  9190 16876 ... 11232  1132  1022]  fibroblast  TS_Vasculature
# 2  [ 3878  9009  4115 ...  4697 10362 12098]  fibroblast  TS_Vasculature
# 3  [ 3878 16916 18367 ... 15470  3946  2153]  fibroblast  TS_Vasculature
# 4  [ 6196 16916 10920 ...  7629 10148 17125]  fibroblast  TS_Vasculature
#
#   length      ignore standardized_cell_type  broad_type __index_level_0__  \
# 0   2048  fibroblast             Fibroblast  fibroblast            109770
# 1   2048  fibroblast             Fibroblast  fibroblast            109771
# 2   2048  fibroblast             Fibroblast  fibroblast            109774
# 3   2048  fibroblast             Fibroblast  fibroblast            109776
# 4   2048  fibroblast             Fibroblast  fibroblast            109777
#
#   cell_id recipe     type
# 0  cell_1    raw  initial
# 1  cell_2    raw  initial
# 2  cell_3    raw  initial
# 3  cell_4    raw  initial
# 4  cell_5    raw  initial
# /tmp/ipykernel_3399698/3223748096.py:9: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   initial_adata.uns['obs_backup'] = initial_adata.obs.copy()

# %%
# # We need to define a function to get the k means PREIMAGE: what cluster they map into
# # key is made from reprog 's dataframes, that's why we ran that code first 
# key_df = pd.DataFrame({
#     'recipe_number': reprog_centroid_adata_wid.obs['recipe_number'].copy(),
#     'kmeans_cluster': reprog_centroid_adata_wid.obs['kmeans_cluster'].copy() 
#     })

# key_df.head()

# %%
#initial_adata.obs['kmeans_cluster'] = initial_kmeans.labels_
initial_adata.obs['recipe_name'] = np.nan
initial_adata.obs['recipe_number'] = np.nan
initial_adata.obs['cell_id'] = initial_adata.uns['obs_backup']['cell_id']
initial_adata.obs['type'] = 'target'

# %%
initial_adata.X.shape
# Out:
# (15308, 512)

# %% [markdown]
# ## HSC Target

# %% [markdown]
# #### Like these other two, we need an anndata object of the true HSC / target cells. This one's obs needs a bit of reformatting though.

# %%
hsc_file_path = '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/hsc_1.h5ad'
hsc_adata = ad.read_h5ad(hsc_file_path)
hsc_adata.X.shape# Ensure hsc_adata is already defined and populated with data
# Out:
# /home/oliven/miniconda3/envs/geneformer2/lib/python3.10/site-packages/anndata/_core/aligned_df.py:67: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# (20090, 512)

# %%
# 1. Check the contents of the original obs
print("Original obs contents:")
print(hsc_adata.obs.head())

# 2. Create the backup
hsc_adata.uns['obs_backup'] = hsc_adata.obs.copy()

# 3. Verify the backup was created correctly
print("Contents of obs_backup after creation:")
print(hsc_adata.uns['obs_backup'].head())

# 4. Clear the original obs
hsc_adata.obs = pd.DataFrame(index=hsc_adata.obs.index)

# 5. Check the contents of the cleared obs and the backup
print("Contents of cleared obs:")
print(hsc_adata.obs.head())

print("Contents of obs_backup after clearing original obs:")
print(hsc_adata.uns['obs_backup'].head())



hsc_adata.obs['kmeans_cluster'] = np.nan # since intermed step
hsc_adata.obs['recipe_name'] = np.nan
hsc_adata.obs['recipe_number'] = np.nan
hsc_adata.obs['cell_id'] = hsc_adata.uns['obs_backup']['cell_id']
hsc_adata.obs['type'] = 'target'
# Out:
# Original obs contents:
#                                    input_ids cell_type              dataset  \
# 0  [14577 17163 10265 ...   852  1582  6234]       HSC  weng_old1_BMMC_HSPC
# 1  [14577  3649 17163 ...  8959  1732 18513]       HSC  weng_old1_BMMC_HSPC
# 2  [10062  3659 17163 ...  6349  3387  8304]       HSC  weng_old1_BMMC_HSPC
# 3  [17163 10265  7725 ...   512  8919 17997]       HSC  weng_old1_BMMC_HSPC
# 4  [14577 10265  1734 ...  1537  1532  4065]       HSC  weng_old1_BMMC_HSPC
#
#   length ignore standardized_cell_type       broad_type __index_level_0__  \
# 0   2048    HSC                    HSC  stem/progenitor                 3
# 1   2048    HSC                    HSC  stem/progenitor                33
# 2   2048    HSC                    HSC  stem/progenitor                58
# 3   1743    HSC                    HSC  stem/progenitor               308
# 4   2048    HSC                    HSC  stem/progenitor               341
#
#   cell_id recipe    type
# 0   hsc_1    nan  target
# 1   hsc_2    nan  target
# 2   hsc_3    nan  target
# 3   hsc_4    nan  target
# 4   hsc_5    nan  target
# Contents of obs_backup after creation:
#                                    input_ids cell_type              dataset  \
# 0  [14577 17163 10265 ...   852  1582  6234]       HSC  weng_old1_BMMC_HSPC
# 1  [14577  3649 17163 ...  8959  1732 18513]       HSC  weng_old1_BMMC_HSPC
# 2  [10062  3659 17163 ...  6349  3387  8304]       HSC  weng_old1_BMMC_HSPC
# 3  [17163 10265  7725 ...   512  8919 17997]       HSC  weng_old1_BMMC_HSPC
# 4  [14577 10265  1734 ...  1537  1532  4065]       HSC  weng_old1_BMMC_HSPC
#
#   length ignore standardized_cell_type       broad_type __index_level_0__  \
# 0   2048    HSC                    HSC  stem/progenitor                 3
# 1   2048    HSC                    HSC  stem/progenitor                33
# 2   2048    HSC                    HSC  stem/progenitor                58
# 3   1743    HSC                    HSC  stem/progenitor               308
# 4   2048    HSC                    HSC  stem/progenitor               341
#
#   cell_id recipe    type
# 0   hsc_1    nan  target
# 1   hsc_2    nan  target
# 2   hsc_3    nan  target
# 3   hsc_4    nan  target
# 4   hsc_5    nan  target
# Contents of cleared obs:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]
# Contents of obs_backup after clearing original obs:
#                                    input_ids cell_type              dataset  \
# 0  [14577 17163 10265 ...   852  1582  6234]       HSC  weng_old1_BMMC_HSPC
# 1  [14577  3649 17163 ...  8959  1732 18513]       HSC  weng_old1_BMMC_HSPC
# 2  [10062  3659 17163 ...  6349  3387  8304]       HSC  weng_old1_BMMC_HSPC
# 3  [17163 10265  7725 ...   512  8919 17997]       HSC  weng_old1_BMMC_HSPC
# 4  [14577 10265  1734 ...  1537  1532  4065]       HSC  weng_old1_BMMC_HSPC
#
#   length ignore standardized_cell_type       broad_type __index_level_0__  \
# 0   2048    HSC                    HSC  stem/progenitor                 3
# 1   2048    HSC                    HSC  stem/progenitor                33
# 2   2048    HSC                    HSC  stem/progenitor                58
# 3   1743    HSC                    HSC  stem/progenitor               308
# 4   2048    HSC                    HSC  stem/progenitor               341
#
#   cell_id recipe    type
# 0   hsc_1    nan  target
# 1   hsc_2    nan  target
# 2   hsc_3    nan  target
# 3   hsc_4    nan  target
# 4   hsc_5    nan  target

# %% [markdown]
# # Compute the Centroids

# %% [markdown]
# #### For our plotting, later, we used Fibroblast Centroid - 1, In Silico Perturbed (ISP) - 10, and HSC - 1 (# Clusters Per Recipe).  The others are there if we need them later.

# %% [markdown]
# ## Fibroblast Centroid - 1

# %%
fibroblast_centroid = initial_adata.X.mean(axis=0)
fibroblast_centroid = np.reshape(initial_adata.X.mean(axis=0), (1, -1))

# %% [markdown]
# ## In Silico Centroids - 10

# %% [markdown]
# #### We don't need these; the 10 in-silico clusters per recipe are in the anndata object already.

# %%
# probably trash

# all_cluster_centroids = ad.AnnData(X=np.empty((0, reprog_centroid_adata_wid.shape[1])))
# all_cluster_centroids_list = []

# cluster_nums = reprog_centroid_adata_wid.obs['kmeans_cluster'].unique().tolist()
# recipe_nums = reprog_centroid_adata_wid.obs['recipe_number'].unique().tolist()

# for recipe in recipe_nums:
#     for cluster in cluster_nums:
#         file_cluster_adata = reprog_centroid_adata_wid[reprog_centroid_adata_wid.obs['kmeans_cluster'] == cluster]
#         file_cluster_centroid = file_cluster_adata.X.mean(axis=0)  # Calculate the mean across rows
#         file_cluster_centroid_adata = ad.AnnData(X=file_cluster_centroid.reshape(1, -1))
#         all_cluster_centroids_list.append(file_cluster_centroid_adata)

# all_cluster_centroids = ad.concat(all_cluster_centroids_list, axis=0)
# all_cluster_centroids.obs.head()

# %% [markdown]
# ## HSC Centroids - 10

# %% [markdown]
# #### The following code works fine.  It is commented out because we do not use it.

# %%
# import anndata as ad
# import numpy as np
# from sklearn.cluster import KMeans

# hsc_kmeans = KMeans(n_clusters=10, random_state=0).fit(hsc_adata.X)

# hsc_adata.obs['kmeans_cluster'] = hsc_kmeans.labels_

# hsc_adata.obs = hsc_adata.obs.sort_values(by=['kmeans_cluster'])

# cluster_numbers = hsc_adata.obs['kmeans_cluster'].unique().tolist()

# all_cluster_centroids_list = []

# for cluster in cluster_numbers:
#     cluster_adata = hsc_adata[hsc_adata.obs['kmeans_cluster'] == cluster]
    
#     if cluster_adata.n_obs == 0:
#         continue
    
#     cluster_centroid = cluster_adata.X.mean(axis=0)
    
#     cluster_centroid_adata = ad.AnnData(X=cluster_centroid.reshape(1, -1))
    
#     all_cluster_centroids_list.append(cluster_centroid_adata)

# if all_cluster_centroids_list:
#     all_cluster_centroids = ad.concat(all_cluster_centroids_list, axis=0)
# else:
#     all_cluster_centroids = ad.AnnData(X=np.empty((0, hsc_adata.X.shape[1])))

# print(all_cluster_centroids)

# %% [markdown]
# ## HSC Centroids - 1

# %%
centroid = hsc_adata.X.mean(axis=0)
centroid = centroid.reshape(1,-1)
hsc_adata_1 = ad.AnnData(X = centroid)
hsc_adata_1.X
# Out:
# array([[ 1.16179183e-01, -2.89754152e-01,  1.46902955e+00,
#         -2.67380718e-02, -5.81506848e-01, -2.16522861e+00,
#         -1.78843051e-01, -5.89545429e-01, -1.41402379e-01,
#          1.28119364e-01,  6.98329031e-01,  3.66711877e-02,
#         -1.89513236e-01,  3.28406513e-01, -6.12913549e-01,
#         -1.45273030e-01,  5.51942885e-01, -6.64202571e-01,
#          3.25894445e-01,  1.26985002e+00, -2.36288905e-02,
#         -1.71297562e+00, -8.92294943e-02, -4.20053154e-01,
#          3.11631225e-02, -3.30170959e-01, -9.88283575e-01,
#          8.36618125e-01,  4.55178060e-02,  1.77251436e-02,
#          3.78184080e-01,  3.58976983e-02,  9.89528000e-01,
#         -7.34287426e-02, -2.21309409e-01,  1.86699063e-01,
#         -6.49069190e-01, -7.08908558e-01, -3.07872687e-02,
#          2.62170881e-01,  5.49614251e-01,  2.57112414e-01,
#         -7.65598536e-01, -1.84915796e-01, -1.32773578e-01,
#          4.15289812e-02,  6.69853508e-01, -6.96526647e-01,
#         -7.52745848e-03, -7.00702220e-02, -3.94886881e-01,
#         -5.96508443e-01,  4.00588900e-01, -1.31626666e+00,
#         -4.99279471e-03, -3.57704759e-01,  1.23567432e-02,
#          5.05248129e-01,  9.77461785e-02, -4.34644550e-01,
#         -6.92352533e-01, -4.30181585e-02,  1.10080577e-02,
#          2.42205128e-01, -6.44623876e-01, -4.27085757e-02,
#         -2.05315351e-02,  5.80019534e-01,  1.57736942e-01,
#         -2.02335394e-03,  1.01869144e-01,  1.76828817e-01,
#         -6.59641773e-02,  4.77511317e-01,  6.26370609e-01,
#          5.17118335e-01,  3.06703538e-01,  2.32895240e-01,
#          9.28484797e-01, -3.88940781e-01, -6.21546447e-01,
#         -1.38043329e-01, -1.08551407e+00, -2.25569797e+00,
#         -5.03122807e-01,  4.83721234e-02, -9.28774104e-02,
#          7.47590840e-01, -8.68356347e-01,  2.57677436e-02,
#         -5.87128460e-01, -4.28191245e-01, -4.42821622e-01,
#          8.49963844e-01, -1.48551035e+00, -3.52755010e-01,
#         -4.25419539e-01,  9.50771451e-01,  1.55646503e+00,
#          9.93971452e-02, -8.78367543e-01, -6.39482141e-02,
#         -2.41751552e-01,  8.62406418e-02,  6.01942278e-02,
#          1.11487818e+00, -2.10953709e-02,  1.89721659e-01,
#         -5.66016100e-02, -6.14744425e-01, -9.40761939e-02,
#         -1.02198744e+00, -3.86040062e-02, -3.09302360e-01,
#         -3.61411452e-01,  4.82783765e-01, -2.51762494e-02,
#         -8.72812510e-01, -1.37100697e-01, -2.40400362e+00,
#          2.57287491e-02,  2.46839121e-01,  4.07609254e-01,
#         -2.43307501e-02, -1.40047097e+00,  1.03712535e+00,
#         -3.14491242e-01, -1.08598612e-01, -1.75641704e-04,
#          5.93060315e-01, -2.35359621e+00,  2.20903969e+00,
#          4.88859892e-01, -1.37862134e+00, -4.55192983e-01,
#          1.08618140e+00,  1.32908189e+00, -8.93162787e-01,
#         -1.08820558e+00,  2.57444829e-01, -2.26843372e-01,
#          1.46706641e+00,  1.02761500e-01,  6.64735734e-02,
#          3.06476176e-01, -7.90583529e-03,  3.18449825e-01,
#         -9.58136767e-02, -3.42653632e-01,  4.95941222e-01,
#          4.85820532e-01,  7.92358100e-01,  7.64518380e-02,
#         -6.84909344e-01, -3.70526314e-01, -4.52781290e-01,
#          1.88266671e+00, -4.01690722e-01, -2.44259715e-01,
#          9.65461805e-02,  9.60387215e-02,  6.52442932e-01,
#         -4.22367066e-01,  3.11597615e-01, -1.86048818e+00,
#         -8.00852597e-01, -8.08996022e-01, -6.03334233e-02,
#          1.35087103e-01, -1.36384785e-01,  1.29657343e-01,
#          9.72854793e-01,  1.03996658e+00,  5.36157712e-02,
#          1.10899770e+00, -6.78913176e-01, -8.21606576e-01,
#         -4.53037918e-02, -4.66250062e-01, -6.06623828e-01,
#         -2.11973995e-01,  3.09576184e-01,  3.85089129e-01,
#          4.52925116e-01, -7.87717700e-01, -2.24120528e-01,
#         -5.42927504e-01, -2.13815123e-01,  7.68115282e-01,
#          3.31628742e-03,  7.52171993e-01, -1.35508791e-01,
#          9.69832465e-02, -1.20194054e+00, -8.76822352e-01,
#         -2.58824497e-01, -2.01248690e-01,  4.63342488e-01,
#          2.12450027e-02,  2.92522460e-01, -1.17417741e+00,
#          2.33782306e-01, -2.29292259e-01,  1.29700392e-01,
#          1.20447099e-01,  4.86506969e-01,  3.39614511e-01,
#          6.21947646e-01, -8.82999241e-01,  2.74930745e-01,
#          5.23665011e-01, -3.94623846e-01, -5.56640863e-01,
#         -3.08492064e-01, -2.82081187e-01,  7.75874376e-01,
#         -1.94487274e-01, -1.07785761e+00, -3.78495944e-03,
#          8.23531508e-01,  2.21418992e-01, -4.51397616e-03,
#         -5.02304256e-01,  8.95310640e-01,  5.21211267e-01,
#          1.46981746e-01, -3.58528227e-01,  2.19095755e+00,
#         -1.72653532e+00, -3.58710468e-01, -3.65669757e-01,
#          2.99547970e-01,  8.24789226e-01, -5.02003372e-01,
#          6.62590623e-01,  9.67454195e-01,  1.55261025e-01,
#         -1.48602593e+00, -8.92399028e-02, -2.34467402e-01,
#          1.74933812e-04,  1.77928939e-01, -9.46867824e-01,
#          4.50655110e-02,  1.88051653e+00, -2.08706432e-03,
#         -1.39717028e-01,  2.76019782e-01,  9.15100332e-03,
#          3.64696711e-01, -5.87311447e-01, -2.04160914e-01,
#         -4.61635530e-01, -2.68555015e-01,  3.35882097e-01,
#          1.50021598e-01,  1.14932507e-01,  1.07508097e-02,
#         -1.84261411e-01,  8.56316611e-02, -2.41779983e-01,
#         -2.15423584e-01,  4.44457263e-01, -2.32551470e-01,
#          4.54795696e-02,  2.03708515e-01, -4.88257185e-02,
#         -6.95229411e-01, -5.07644892e-01, -9.66431260e-01,
#         -1.48143291e+00,  5.68055570e-01, -9.40552726e-02,
#          2.31396365e+00, -3.42537910e-02,  3.79197374e-02,
#         -3.12107593e-01,  6.40142620e-01, -1.15255451e+00,
#         -3.99877280e-01,  1.48759520e+00, -1.18904710e+00,
#         -1.12402529e-01,  3.81347209e-01,  1.12866676e+00,
#         -3.48713607e-01, -5.88856399e-01,  1.46184945e-02,
#          6.78306043e-01,  5.48118472e-01,  2.56425053e-01,
#         -1.39218748e-01, -4.54060823e-01,  1.23488104e+00,
#          1.73882678e-01, -4.46929306e-01,  2.33306694e+00,
#         -2.52807319e-01,  3.54688138e-01, -1.76688865e-01,
#         -6.66946352e-01,  7.54795551e-01, -3.20877099e+00,
#          3.27232122e-01,  5.83716750e-01, -1.15443982e-01,
#         -2.06197008e-01, -1.30670842e-05, -3.68787080e-01,
#         -2.27764785e-01, -7.24179089e-01, -2.78514445e-01,
#          5.35264850e-01, -2.09367347e+00,  7.79911757e-01,
#          7.51099706e-01,  5.74153244e-01,  5.14911532e-01,
#          6.54384434e-01,  4.41143773e-02, -4.07197587e-02,
#         -8.33639860e-01,  1.04164064e-01,  1.67205766e-01,
#         -2.89165005e-02,  2.54142106e-01, -3.05694640e-01,
#         -6.20260417e-01, -1.04898906e+00, -4.37532365e-01,
#          9.09064770e-01, -4.12441581e-01,  6.65353596e-01,
#         -1.08359791e-01, -1.26884186e+00,  3.69445831e-01,
#          4.81500238e-01,  1.06763601e+00, -5.64213395e-01,
#         -3.00967872e-01, -3.41886997e-01, -3.82699817e-01,
#          3.25026333e-01,  5.30918300e-01, -2.39584401e-01,
#          2.03280538e-01,  7.10179746e-01,  3.46639287e-03,
#         -3.79862428e-01, -2.62592465e-01, -5.85587680e-01,
#          7.86020085e-02,  8.99301648e-01,  4.82931703e-01,
#          1.03464037e-01,  1.56174004e-01,  3.61689746e-01,
#         -3.12639438e-02, -1.10716537e-01,  1.55726261e-02,
#         -1.19011968e-01, -1.10569052e-01, -1.10866106e+00,
#         -8.79066214e-02,  1.04582019e-01, -2.64697671e-01,
#         -1.98765527e-02,  5.79287231e-01,  3.60248864e-01,
#          4.72897053e-01, -9.11921620e-01, -4.17318612e-01,
#         -1.13803232e+00,  3.58212404e-02, -3.45952988e-01,
#         -3.74912401e-03, -4.56463724e-01, -7.24919081e-01,
#         -5.16780876e-02,  1.59355804e-01,  4.96878296e-01,
#         -1.18526411e+00,  4.54833657e-01, -5.54881878e-02,
#          2.66470402e-01, -2.06350014e-01, -1.81631207e-01,
#          4.97360945e-01, -5.45463562e-01,  3.11189055e-01,
#          7.51997352e-01, -2.71146834e-01,  1.23873748e-01,
#          1.09067656e-01, -2.64686421e-02,  1.78367227e-01,
#          4.97633144e-02,  1.08336449e-01,  3.35924774e-01,
#          1.40137970e-01, -2.99493670e-01,  9.54941139e-02,
#          7.57768035e-01,  2.66593188e-01,  7.04930067e-01,
#         -9.41288397e-02, -1.72194147e+00,  9.15737867e-01,
#         -3.38603616e-01, -4.30046380e-01,  5.74918427e-02,
#         -3.12498736e+00, -9.15311202e-02, -4.38713096e-02,
#          2.38238722e-01,  6.97168335e-02,  1.92208797e-01,
#         -5.42100333e-02,  1.84118692e-02, -4.66884188e-02,
#          1.52584994e+00, -3.77856754e-02, -9.07547355e-01,
#         -2.37954915e-01,  6.32345825e-02,  1.51960263e-02,
#          2.09768400e-01,  8.32964659e-01,  3.21646750e-01,
#         -2.63995171e-01, -6.00060046e-01, -1.11282933e+00,
#          3.65984552e-02,  1.93897367e-01,  8.69896412e-01,
#          4.26138863e-02, -3.10337216e-01,  4.51022208e-01,
#         -1.57265365e-02,  4.47717786e-01, -1.16867358e-02,
#         -7.95273960e-01,  3.43131334e-01, -3.35282087e+00,
#         -1.23100924e+00, -2.04832718e-01,  1.88961886e-02,
#          2.02322721e-01,  2.89258361e-01,  3.82740021e-01,
#          5.14489293e-01, -8.04380655e-01, -5.10168791e-01,
#          1.77466047e+00,  8.88344347e-01,  3.21457148e-01,
#          7.49113441e-01,  9.86447558e-02,  8.07380438e-01,
#         -6.34133965e-02, -8.33006382e-01, -5.42964637e-01,
#          2.03314200e-01,  3.57906446e-02,  3.62782508e-01,
#          7.59382725e-01, -5.18731177e-01,  2.19714001e-01,
#         -3.98321629e-01, -2.50510246e-01,  2.54303869e-02,
#          1.80377960e-01, -3.03345084e-01,  4.26887274e-01,
#          8.53778303e-01, -1.06963730e+00, -2.13048965e-01,
#          1.36260462e+00,  6.83459193e-02, -5.05017079e-02,
#          8.10249373e-02,  3.27242948e-02, -5.82357422e-02,
#         -9.18850005e-02,  9.03923437e-02,  3.39786887e-01,
#          3.13226759e-01,  5.40624633e-02, -1.64174050e-01,
#          3.10052842e-01,  9.13882852e-01, -1.15074478e-01,
#          7.06056580e-02, -9.89803135e-01,  1.43759131e-01,
#          1.93922973e+00, -6.20272398e-01,  3.76844476e-03,
#          1.08034480e+00,  1.18209071e-01, -1.19813874e-01,
#          4.94517386e-01,  1.05842698e+00,  1.02265918e+00,
#         -2.37141848e-01,  1.59444964e+00,  1.00045666e-01,
#          5.53588748e-01,  8.17971528e-02, -3.60943601e-02,
#         -8.97852063e-01, -1.07992560e-01]], dtype=float32)

# %% [markdown]
# # Distance Calculations!

# %% [markdown]
# #### Throughout this, the dataframe that we are updating with cumulative results is called results_df.  The dataframe with summary statistics of each recipe is called condensed_results.

# %%
reprog_centroid_adata_wid.obs
# Out:
#       kmeans_cluster                  recipe_name  recipe_number  \
# 0                  0   GATA2;GFI1B;FOS;STAT5A;REL              1
# 1                  1   GATA2;GFI1B;FOS;STAT5A;REL              1
# 2                  2   GATA2;GFI1B;FOS;STAT5A;REL              1
# 3                  3   GATA2;GFI1B;FOS;STAT5A;REL              1
# 4                  4   GATA2;GFI1B;FOS;STAT5A;REL              1
# ...              ...                          ...            ...
# 2515               5  FOSB;IKZF1;RUNX3;MEF2C;ETV6            252
# 2516               6  FOSB;IKZF1;RUNX3;MEF2C;ETV6            252
# 2517               7  FOSB;IKZF1;RUNX3;MEF2C;ETV6            252
# 2518               8  FOSB;IKZF1;RUNX3;MEF2C;ETV6            252
# 2519               9  FOSB;IKZF1;RUNX3;MEF2C;ETV6            252
#
#                                                 cell_id          type  \
# 0     cell_20;cell_23;cell_44;cell_58;cell_71;cell_8...  reprogrammed
# 1     cell_4;cell_6;cell_8;cell_12;cell_13;cell_15;c...  reprogrammed
# 2     cell_9;cell_31;cell_46;cell_50;cell_53;cell_54...  reprogrammed
# 3     cell_14;cell_194;cell_207;cell_233;cell_367;ce...  reprogrammed
# 4     cell_2;cell_3;cell_24;cell_57;cell_81;cell_135...  reprogrammed
# ...                                                 ...           ...
# 2515  cell_481;cell_753;cell_2277;cell_4639;cell_512...  reprogrammed
# 2516  cell_25;cell_89;cell_102;cell_136;cell_183;cel...  reprogrammed
# 2517  cell_28;cell_39;cell_43;cell_50;cell_65;cell_1...  reprogrammed
# 2518  cell_3;cell_5;cell_7;cell_11;cell_19;cell_21;c...  reprogrammed
# 2519  cell_8;cell_12;cell_13;cell_15;cell_18;cell_20...  reprogrammed
#
#       cluster_number
# 0                  1
# 1                  2
# 2                  3
# 3                  4
# 4                  5
# ...              ...
# 2515            2516
# 2516            2517
# 2517            2518
# 2518            2519
# 2519            2520
#
# [2520 rows x 6 columns]

# %% [markdown]
# ## Centroids to HSC-1

# %%
reprog_centroid_adata_wid.obs.tail(10)
# Out:
#       kmeans_cluster                  recipe_name  recipe_number  \
# 2510               0  FOSB;IKZF1;RUNX3;MEF2C;ETV6            252
# 2511               1  FOSB;IKZF1;RUNX3;MEF2C;ETV6            252
# 2512               2  FOSB;IKZF1;RUNX3;MEF2C;ETV6            252
# 2513               3  FOSB;IKZF1;RUNX3;MEF2C;ETV6            252
# 2514               4  FOSB;IKZF1;RUNX3;MEF2C;ETV6            252
# 2515               5  FOSB;IKZF1;RUNX3;MEF2C;ETV6            252
# 2516               6  FOSB;IKZF1;RUNX3;MEF2C;ETV6            252
# 2517               7  FOSB;IKZF1;RUNX3;MEF2C;ETV6            252
# 2518               8  FOSB;IKZF1;RUNX3;MEF2C;ETV6            252
# 2519               9  FOSB;IKZF1;RUNX3;MEF2C;ETV6            252
#
#                                                 cell_id          type  \
# 2510  cell_4;cell_9;cell_26;cell_31;cell_36;cell_46;...  reprogrammed
# 2511  cell_6;cell_16;cell_17;cell_22;cell_29;cell_33...  reprogrammed
# 2512  cell_143;cell_191;cell_197;cell_203;cell_322;c...  reprogrammed
# 2513  cell_2;cell_14;cell_182;cell_194;cell_196;cell...  reprogrammed
# 2514  cell_1;cell_10;cell_45;cell_177;cell_275;cell_...  reprogrammed
# 2515  cell_481;cell_753;cell_2277;cell_4639;cell_512...  reprogrammed
# 2516  cell_25;cell_89;cell_102;cell_136;cell_183;cel...  reprogrammed
# 2517  cell_28;cell_39;cell_43;cell_50;cell_65;cell_1...  reprogrammed
# 2518  cell_3;cell_5;cell_7;cell_11;cell_19;cell_21;c...  reprogrammed
# 2519  cell_8;cell_12;cell_13;cell_15;cell_18;cell_20...  reprogrammed
#
#       cluster_number
# 2510            2511
# 2511            2512
# 2512            2513
# 2513            2514
# 2514            2515
# 2515            2516
# 2516            2517
# 2517            2518
# 2518            2519
# 2519            2520

# %%
def get_reprog_recipe_name(specific_cluster):
    specific_recipe = reprog_centroid_adata_wid.obs.loc[reprog_centroid_adata_wid.obs['cluster_number'] == specific_cluster, 'recipe_name'].values[0]
    return specific_recipe
# test
get_reprog_recipe_name(2518)
# Out:
# 'FOSB;IKZF1;RUNX3;MEF2C;ETV6'

# %%
# Verified that they are not sparse

Xb = np.array(reprog_centroid_adata_wid.X)
Xc = np.array(hsc_adata_1.X)

reprog_to_hsc_1_cdist = cdist(Xb, Xc, metric='cosine')

# %%
import pandas as pd

# Reset index to align DataFrames
results_df = pd.DataFrame()
#results_df = results_df.reset_index(drop=True)
reprog_centroid_adata_wid.obs = reprog_centroid_adata_wid.obs.reset_index(drop=True)

# Perform the assignment
results_df['cluster_number'] = reprog_centroid_adata_wid.obs['cluster_number']
results_df['recipe_number'] = reprog_centroid_adata_wid.obs['recipe_number']

results_df['recipe'] = results_df['cluster_number'].apply(get_reprog_recipe_name)
results_df['reprog_to_hsc_1'] = reprog_to_hsc_1_cdist

results_df.head(11)
# Out:
#     cluster_number  recipe_number                       recipe  \
# 0                1              1   GATA2;GFI1B;FOS;STAT5A;REL
# 1                2              1   GATA2;GFI1B;FOS;STAT5A;REL
# 2                3              1   GATA2;GFI1B;FOS;STAT5A;REL
# 3                4              1   GATA2;GFI1B;FOS;STAT5A;REL
# 4                5              1   GATA2;GFI1B;FOS;STAT5A;REL
# 5                6              1   GATA2;GFI1B;FOS;STAT5A;REL
# 6                7              1   GATA2;GFI1B;FOS;STAT5A;REL
# 7                8              1   GATA2;GFI1B;FOS;STAT5A;REL
# 8                9              1   GATA2;GFI1B;FOS;STAT5A;REL
# 9               10              1   GATA2;GFI1B;FOS;STAT5A;REL
# 10              11              2  GATA2;GFI1B;FOS;STAT5A;FOSB
#
#     reprog_to_hsc_1
# 0          0.872306
# 1          0.886576
# 2          0.859303
# 3          0.689501
# 4          0.746955
# 5          0.825973
# 6          0.837030
# 7          0.736552
# 8          0.887333
# 9          0.779201
# 10         0.876516

# %% [markdown]
# ## Initial Fibroblast to Centroid

# %% [markdown]
# ### Preimage to Centroid

# %% [markdown]
# #### Getting our initial fibs again

# %% [markdown]
# #### DRAFT of Computing these distances

# %%
import os
import re

def list_reprogramming_jobs(directory, start_job_number, end_job_number):
    """
    List and sort files in the given directory by job number within the specified range.

    Parameters:
    directory (str): The directory containing the files.
    start_job_number (int): The starting job number.
    end_job_number (int): The ending job number.

    Returns:
    list: A sorted list of file names within the specified job number range.
    """
    # List all files in the directory
    files = os.listdir(directory)

    # Define a regex pattern to extract job numbers
    pattern = re.compile(r'_job_number_(\d+)\.h5ad$')

    # Create a list of tuples (job_number, file_name)
    files_with_job_numbers = []
    for file in files:
        match = pattern.search(file)
        if match:
            job_number = int(match.group(1))
            if start_job_number <= job_number <= end_job_number:
                files_with_job_numbers.append((job_number, file))

    # Sort files by job number
    files_with_job_numbers.sort(key=lambda x: x[0])

    # Extract sorted file names
    sorted_files = [file for _, file in files_with_job_numbers]

    return sorted_files

# Example usage
directory = '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/'

files_in_directory = list_reprogramming_jobs(directory, 1, 252)
files_in_directory = [directory + file for file in files_in_directory]
files_in_directory
# Out:
# ['/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_02-44-44_job_number_1.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_02-44-45_job_number_2.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_02-44-53_job_number_3.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_02-44-49_job_number_4.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_02-45-28_job_number_5.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_02-44-55_job_number_6.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_02-45-23_job_number_7.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_02-44-57_job_number_8.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_03-16-56_job_number_9.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_03-16-48_job_number_10.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_03-16-43_job_number_11.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_03-17-04_job_number_12.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_03-16-52_job_number_13.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_03-16-44_job_number_14.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_03-17-52_job_number_15.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_03-18-00_job_number_16.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_03-27-40_job_number_17.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_03-31-58_job_number_18.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_03-48-31_job_number_19.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_03-48-37_job_number_20.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_03-48-37_job_number_21.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_03-49-01_job_number_22.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_03-49-07_job_number_23.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_03-49-44_job_number_24.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_03-50-17_job_number_25.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_03-50-52_job_number_26.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_03-51-51_job_number_27.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_03-56-06_job_number_28.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_04-21-03_job_number_29.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_04-21-21_job_number_30.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_04-21-34_job_number_31.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_04-21-41_job_number_32.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_04-21-34_job_number_33.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_04-22-21_job_number_34.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_04-23-32_job_number_35.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_04-24-16_job_number_36.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_04-16-31_job_number_37.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_04-20-20_job_number_38.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_04-40-49_job_number_39.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_04-44-24_job_number_40.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_04-46-22_job_number_41.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_04-46-12_job_number_42.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_04-46-42_job_number_43.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_04-53-19_job_number_44.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_04-53-52_job_number_45.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_04-54-39_job_number_46.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_04-54-53_job_number_47.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_04-56-01_job_number_48.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_05-05-35_job_number_49.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_05-15-26_job_number_50.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_05-10-22_job_number_51.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_05-10-07_job_number_52.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_05-10-55_job_number_53.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_05-24-48_job_number_54.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_05-25-08_job_number_55.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_05-25-48_job_number_56.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_05-25-46_job_number_57.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_05-26-49_job_number_58.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_05-29-54_job_number_59.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_05-33-52_job_number_60.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_05-34-28_job_number_61.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_05-35-00_job_number_62.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_05-46-31_job_number_63.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_05-56-45_job_number_64.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_05-57-15_job_number_65.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_05-57-58_job_number_66.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_05-57-43_job_number_67.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_05-59-04_job_number_68.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_06-02-51_job_number_69.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_06-07-19_job_number_70.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_06-20-04_job_number_71.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_06-14-21_job_number_72.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_06-29-31_job_number_73.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_06-30-17_job_number_74.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_06-31-23_job_number_75.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_06-32-17_job_number_76.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_06-34-03_job_number_77.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_06-36-41_job_number_78.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_06-40-10_job_number_79.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_06-38-03_job_number_80.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_06-52-01_job_number_81.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_07-00-36_job_number_82.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_07-01-47_job_number_83.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_07-03-40_job_number_84.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_07-03-52_job_number_85.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_07-06-36_job_number_86.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_07-09-06_job_number_87.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_07-01-47_job_number_88.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_07-03-23_job_number_89.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_07-12-49_job_number_90.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_07-24-29_job_number_91.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_07-31-35_job_number_92.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_07-25-45_job_number_93.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_07-32-54_job_number_94.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_07-27-17_job_number_95.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_07-35-50_job_number_96.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_07-34-58_job_number_97.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_07-39-11_job_number_98.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_07-41-20_job_number_99.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_07-45-19_job_number_100.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_07-57-04_job_number_101.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_07-50-00_job_number_102.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_07-51-42_job_number_103.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_08-03-04_job_number_104.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_08-04-28_job_number_105.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_08-06-33_job_number_106.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_08-09-17_job_number_107.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_08-11-16_job_number_108.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_08-13-55_job_number_109.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_08-17-49_job_number_110.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_08-14-03_job_number_111.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_08-15-34_job_number_112.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_08-29-33_job_number_113.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_08-34-55_job_number_114.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_08-35-56_job_number_115.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_08-38-08_job_number_116.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_08-41-28_job_number_117.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_08-42-51_job_number_118.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_08-45-35_job_number_119.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_08-38-05_job_number_120.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_08-39-21_job_number_121.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_09-01-18_job_number_122.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_09-06-16_job_number_123.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_09-07-15_job_number_124.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_09-01-51_job_number_125.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_09-09-26_job_number_126.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_09-03-44_job_number_127.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_09-13-27_job_number_128.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_09-14-52_job_number_129.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_09-17-24_job_number_130.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_09-18-08_job_number_131.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_09-25-25_job_number_132.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_09-25-30_job_number_133.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_09-28-20_job_number_134.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_09-37-17_job_number_135.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_09-38-12_job_number_136.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_09-40-42_job_number_137.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_09-44-48_job_number_138.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_09-46-17_job_number_139.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_09-48-45_job_number_140.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_09-41-54_job_number_141.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_09-49-17_job_number_142.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_09-57-00_job_number_143.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_10-09-44_job_number_144.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_10-10-07_job_number_145.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_10-13-03_job_number_146.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_10-06-44_job_number_147.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_10-15-45_job_number_148.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_10-17-15_job_number_149.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_10-13-12_job_number_150.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_10-17-37_job_number_151.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_10-28-03_job_number_152.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_10-30-52_job_number_153.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_10-41-09_job_number_154.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_10-41-14_job_number_155.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_10-37-16_job_number_156.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_10-44-48_job_number_157.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_10-32-15_job_number_158.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_10-33-21_job_number_159.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_10-43-57_job_number_160.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_10-48-21_job_number_161.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_10-49-22_job_number_162.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_10-49-51_job_number_163.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_10-57-22_job_number_164.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_10-57-26_job_number_165.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_10-59-50_job_number_166.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_11-00-52_job_number_167.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_11-03-47_job_number_168.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_11-04-51_job_number_169.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_11-16-11_job_number_170.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_11-19-59_job_number_171.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_11-18-56_job_number_172.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_11-21-50_job_number_173.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_11-31-28_job_number_174.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_11-35-36_job_number_175.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_11-37-14_job_number_176.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_11-43-17_job_number_177.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_11-47-23_job_number_178.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_11-47-26_job_number_179.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_11-45-00_job_number_180.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_11-49-26_job_number_181.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_11-50-59_job_number_182.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_11-52-45_job_number_183.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_11-58-34_job_number_184.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_11-57-00_job_number_185.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_11-58-59_job_number_186.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_12-07-41_job_number_187.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_12-08-31_job_number_188.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_12-12-30_job_number_189.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_12-04-08_job_number_190.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_12-10-43_job_number_191.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_12-13-14_job_number_192.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_12-16-48_job_number_193.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_12-18-24_job_number_194.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_12-26-19_job_number_195.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_12-27-17_job_number_196.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_12-27-05_job_number_197.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_12-29-46_job_number_198.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_12-29-16_job_number_199.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_12-32-38_job_number_200.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_12-31-28_job_number_201.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_12-31-32_job_number_202.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_12-43-03_job_number_203.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_12-42-52_job_number_204.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_12-44-10_job_number_205.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_12-45-31_job_number_206.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_12-46-40_job_number_207.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_12-44-03_job_number_208.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_12-44-38_job_number_209.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_12-48-13_job_number_210.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_12-58-26_job_number_211.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_12-59-23_job_number_212.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_12-57-24_job_number_213.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_12-56-28_job_number_214.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_13-00-29_job_number_215.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_12-57-02_job_number_216.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_13-01-31_job_number_217.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_13-03-05_job_number_218.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_13-03-51_job_number_219.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_13-08-41_job_number_220.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_13-09-07_job_number_221.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_13-09-36_job_number_222.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_13-14-24_job_number_223.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_13-15-16_job_number_224.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_13-16-25_job_number_225.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_13-17-28_job_number_226.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_13-19-00_job_number_227.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_13-19-59_job_number_228.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_13-21-12_job_number_229.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_13-21-32_job_number_230.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_13-22-10_job_number_231.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_13-30-47_job_number_232.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_13-31-20_job_number_233.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_13-32-44_job_number_234.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_13-33-44_job_number_235.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_13-35-27_job_number_236.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_13-36-08_job_number_237.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_13-33-33_job_number_238.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_13-34-04_job_number_239.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_13-34-39_job_number_240.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_13-47-06_job_number_241.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_13-47-45_job_number_242.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_13-52-04_job_number_243.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_13-49-44_job_number_244.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_13-47-10_job_number_245.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_13-53-37_job_number_246.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_13-52-07_job_number_247.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_14-03-09_job_number_248.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_14-04-57_job_number_249.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_14-05-42_job_number_250.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_14-07-39_job_number_251.h5ad',
#  '/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/working_output/2024-07-31_15-38-49_job_number_252.h5ad']

# %%
# caution, i used some of these variable names later for something else

# # initialize a new results_df column for these results
# results_df['initial_to_reprog']
# #initial_adata.X has shape (15309,512)
# Xa = np.array(initial_adata.X)
# for file in files_in_directory:
#     one_reprog_recipe_adata = ad.read_h5ad(file)
#     Xa = one_reprog_recipe_adata.X
#     one_reprog_recipe_
#     Xb = np.array(reprog_centroid_adata_wid.X)
    
#     print("Reading in a file of size ")
#     print(Xa.size)
    

#     results_df.at['']
# reprog_to_hsc_1_cdist = cdist(Xb, Xc, metric='cosine')

# %% [markdown]
# ### Fibroblast-1 to Reprog-10 (The one we want)

# %%
Xa = np.array(fibroblast_centroid)
# filtering by recipe number, so we get each of the 10 centroids
recipe_num_list = reprog_centroid_adata_wid.obs['recipe_number'].unique().tolist()
#fib_1_to_reprog_10_dists = []
df_f1reprog10 = pd.DataFrame()

for recipe in recipe_num_list: 
    one_reprog_recipe_adata = reprog_centroid_adata_wid[reprog_centroid_adata_wid.obs['recipe_number'] == recipe]

    #I am assuming it will be 10x512, and then the result will be 1x512
    print("Size of the Xb matrix is ")
    print(one_reprog_recipe_adata.X.size)

    Xb = np.array(one_reprog_recipe_adata.X)
    fib_1_to_reprog_10 = cdist(Xa, Xb, metric='cosine')

    print("Size of the cdist vector is ")
    print(fib_1_to_reprog_10.size)

    #structurign for storage
    fib_1_to_reprog_10_flat = fib_1_to_reprog_10.flatten()
    temp_df_f1reprog10 = pd.DataFrame({'distance': fib_1_to_reprog_10_flat})
    df_f1reprog10 = pd.concat([df_f1reprog10, temp_df_f1reprog10], ignore_index=True)

results_df['fib_1_to_reprog_10'] = df_f1reprog10['distance']
# Out:
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10
# Size of the Xb matrix is
# 5120
# Size of the cdist vector is
# 10

# %%
results_df
# Out:
#       cluster_number  recipe_number                       recipe  \
# 0                  1              1   GATA2;GFI1B;FOS;STAT5A;REL
# 1                  2              1   GATA2;GFI1B;FOS;STAT5A;REL
# 2                  3              1   GATA2;GFI1B;FOS;STAT5A;REL
# 3                  4              1   GATA2;GFI1B;FOS;STAT5A;REL
# 4                  5              1   GATA2;GFI1B;FOS;STAT5A;REL
# ...              ...            ...                          ...
# 2515            2516            252  FOSB;IKZF1;RUNX3;MEF2C;ETV6
# 2516            2517            252  FOSB;IKZF1;RUNX3;MEF2C;ETV6
# 2517            2518            252  FOSB;IKZF1;RUNX3;MEF2C;ETV6
# 2518            2519            252  FOSB;IKZF1;RUNX3;MEF2C;ETV6
# 2519            2520            252  FOSB;IKZF1;RUNX3;MEF2C;ETV6
#
#       reprog_to_hsc_1  fib_1_to_reprog_10
# 0            0.872306            0.009301
# 1            0.886576            0.004932
# 2            0.859303            0.001300
# 3            0.689501            0.203887
# 4            0.746955            0.044158
# ...               ...                 ...
# 2515         0.837640            0.065440
# 2516         0.898764            0.005873
# 2517         0.780846            0.009404
# 2518         0.817916            0.015633
# 2519         0.896088            0.005959
#
# [2520 rows x 5 columns]

# %% [markdown]
# ## Fib-1 to HSC-1

# %%
# This is a constant
Xa = np.array(fibroblast_centroid)
Xc = np.array(hsc_adata_1.X)
init_to_fin_dist = cdist(Xa, Xc, metric='cosine')
print(init_to_fin_dist)
# Out:
# [[0.85662723]]

# %%
# Check the columns in results_df
print(results_df.columns)

# Check the first few rows of the DataFrame to see if the column exists
results_df.head()
# Out:
# Index(['cluster_number', 'recipe_number', 'recipe', 'reprog_to_hsc_1',
#        'fib_1_to_reprog_10'],
#       dtype='object')
#    cluster_number  recipe_number                      recipe  reprog_to_hsc_1  \
# 0               1              1  GATA2;GFI1B;FOS;STAT5A;REL         0.872306
# 1               2              1  GATA2;GFI1B;FOS;STAT5A;REL         0.886576
# 2               3              1  GATA2;GFI1B;FOS;STAT5A;REL         0.859303
# 3               4              1  GATA2;GFI1B;FOS;STAT5A;REL         0.689501
# 4               5              1  GATA2;GFI1B;FOS;STAT5A;REL         0.746955
#
#    fib_1_to_reprog_10
# 0            0.009301
# 1            0.004932
# 2            0.001300
# 3            0.203887
# 4            0.044158

# %% [markdown]
# ## Analyzing Distance Results

# %% [markdown]
# ## Extracting Single Cells from a Cluster

# %%
# the above is a little wacky what is condensed_results_sorted doing. this is keeping the same entries and changing the rank or something which is weird. goodnight

# %%
""" 


Note to self: you can switch between ;-separated and list easily with str.split(';', expand=True)
key_df['recipe_number;kmeans_cluster'] = key_df[['recipe_number', 'kmeans_cluster']].agg(';'.join, axis=1)

1. Add a column called 'centroid_index' to the centroid matrix obs, with integer values increasing from 1
2. Write a function, get_initial_cells_in(centroid_index) that:
     a) takes in centroid index and converts the ;-separated string of cell ids into a list of cell ids. already verified it's a one to one map
     b) for each cell_id, restrict the initial_adata object to only have values where the recipe_number matches
        (of what and what? initial_adata.obs and reprog_centroid_adata_wid.obs is the same?) AND the cell is in the list of cell ids from a.
     c) What do we want to return? We want to return an anndata object with the filtering from above.  (Not yet, in a calling of the function) this anndata object
        is going to become an Xa matrix for cdist.  Xb will be the centroid index. 

New Task (Cdist like actually)
For every centroid_index, we want to set Xb to be the centroid that it corresponds to, and call get_initial_cells_in(centroid_index).
This is a cdist between every centroid and the cells that go into it.  Average the values. Add to a dataframe in a cleverish way


"""
# Out:
# " \n\n\nNote to self: you can switch between ;-separated and list easily with str.split(';', expand=True)\nkey_df['recipe_number;kmeans_cluster'] = key_df[['recipe_number', 'kmeans_cluster']].agg(';'.join, axis=1)\n\n1. Add a column called 'centroid_index' to the centroid matrix obs, with integer values increasing from 1\n2. Write a function, get_initial_cells_in(centroid_index) that:\n     a) takes in centroid index and converts the ;-separated string of cell ids into a list of cell ids. already verified it's a one to one map\n     b) for each cell_id, restrict the initial_adata object to only have values where the recipe_number matches\n        (of what and what? initial_adata.obs and reprog_centroid_adata_wid.obs is the same?) AND the cell is in the list of cell ids from a.\n     c) What do we want to return? We want to return an anndata object with the filtering from above.  (Not yet, in a calling of the function) this anndata object\n        is going to become an Xa matrix for cdist.  Xb will be the centroid index. \n\nNew Task (Cdist like actually)\nFor every centroid_index, we want to set Xb to be the centroid that it corresponds to, and call get_initial_cells_in(centroid_index).\nThis is a cdist between every centroid and the cells that go into it.  Average the values. Add to a dataframe in a cleverish way\n\n\n"

# %% [markdown]
# ## Condensed Results Dataframe: About

# %% [markdown]
# #### This is just a dataframe for an at-a-glance overview of the perturbed data.  Commented out because we don't use it.  It does work, though!

# %%
# # you could run this..

# condensed_results_sorted[('rank', '')] = condensed_results[('recipe_diff', 'mean')].sort(ascending=False, method='dense').astype(int)
# condensed_results_sorted.head(10)

# # OR this..

# # Recalculate rank after sorting
# condensed_results_sorted[('rank', '')] = condensed_results_sorted[('reprog_to_hsc_1', 'mean')].rank(ascending=True, method='dense').astype(int)
# condensed_results_sorted.head(10)

# # ... OR this...
# # Recalculate rank after sorting
# condensed_results_sorted[('rank', '')] = condensed_results_sorted[('fib_1_to_reprog_10', 'mean')].rank(ascending=True, method='dense').astype(int)
# condensed_results_sorted.head(10)

# %%
init_to_fin_dist = 0.85662723

# Add 'recipe_diff' column to results_df
results_df['recipe_diff'] = (init_to_fin_dist - results_df['reprog_to_hsc_1']) / init_to_fin_dist

# Group by 'recipe' and calculate mean and std for specified columns
condensed_results = results_df.groupby('recipe').agg({
    'fib_1_to_reprog_10': ['mean', 'std'],
    'reprog_to_hsc_1': ['mean', 'std'],
    'recipe_diff': ['mean', 'std']
}).reset_index()

# Display result
condensed_results.head(12)
# Out:
#                         recipe fib_1_to_reprog_10           reprog_to_hsc_1  \
#                                              mean       std            mean
# 0    FOS;FOSB;IKZF1;MEF2C;ETV6           0.046725  0.067573        0.824107
# 1    FOS;FOSB;IKZF1;RUNX3;ETV6           0.051075  0.071930        0.825219
# 2   FOS;FOSB;IKZF1;RUNX3;MEF2C           0.046791  0.066405        0.829131
# 3    FOS;FOSB;RUNX3;MEF2C;ETV6           0.047985  0.068679        0.827510
# 4   FOS;IKZF1;RUNX3;MEF2C;ETV6           0.042965  0.050146        0.820912
# 5      FOS;REL;FOSB;IKZF1;ETV6           0.035009  0.046722        0.824404
# 6     FOS;REL;FOSB;IKZF1;MEF2C           0.040557  0.052092        0.823132
# 7     FOS;REL;FOSB;IKZF1;RUNX3           0.052220  0.072628        0.819786
# 8      FOS;REL;FOSB;MEF2C;ETV6           0.038973  0.049967        0.825239
# 9      FOS;REL;FOSB;RUNX3;ETV6           0.047426  0.068418        0.828868
# 10    FOS;REL;FOSB;RUNX3;MEF2C           0.048402  0.069161        0.827122
# 11    FOS;REL;IKZF1;MEF2C;ETV6           0.049594  0.068903        0.815696
#
#              recipe_diff
#          std        mean       std
# 0   0.065421    0.037963  0.076370
# 1   0.064389    0.036665  0.075166
# 2   0.063742    0.032098  0.074411
# 3   0.065726    0.033991  0.076727
# 4   0.062646    0.041693  0.073131
# 5   0.065346    0.037616  0.076283
# 6   0.066349    0.039101  0.077453
# 7   0.064550    0.043007  0.075354
# 8   0.066911    0.036641  0.078110
# 9   0.064708    0.032405  0.075538
# 10  0.063879    0.034444  0.074570
# 11  0.068367    0.047782  0.079810

# %%
condensed_results = condensed_results.sort_values(by=('recipe_diff', 'mean'), ascending=False)
condensed_results[('rank', '')] = condensed_results[('recipe_diff', 'mean')].rank(ascending=False).astype(int)


# Reorder columns to place 'rank' on the left
condensed_results = condensed_results[[('rank', ''),
                                       ('recipe', ''),
                                       ('fib_1_to_reprog_10', 'mean'),
                                       ('fib_1_to_reprog_10', 'std'),
                                       ('reprog_to_hsc_1', 'mean'),
                                       ('reprog_to_hsc_1', 'std'),
                                       ('recipe_diff', 'mean'),
                                       ('recipe_diff', 'std')]]

condensed_results[('rank','')].max()
# Out:
# 252

# %%
condensed_results.head(12)
# Out:
#     rank                        recipe fib_1_to_reprog_10            \
#                                                      mean       std
# 50     1     GATA2;FOS;REL;IKZF1;MEF2C           0.055854  0.075408
# 90     2   GATA2;GFI1B;FOS;STAT5A;ETV6           0.054266  0.062601
# 92     3  GATA2;GFI1B;FOS;STAT5A;IKZF1           0.046111  0.066718
# 87     4     GATA2;GFI1B;FOS;REL;RUNX3           0.056104  0.073022
# 156    5  GATA2;STAT5A;REL;IKZF1;MEF2C           0.052726  0.070804
# 158    6   GATA2;STAT5A;REL;MEF2C;ETV6           0.056411  0.078078
# 110    7   GATA2;GFI1B;REL;IKZF1;MEF2C           0.046903  0.068421
# 112    8    GATA2;GFI1B;REL;MEF2C;ETV6           0.056755  0.078779
# 155    9   GATA2;STAT5A;REL;IKZF1;ETV6           0.054358  0.075114
# 109   10    GATA2;GFI1B;REL;IKZF1;ETV6           0.054556  0.075464
# 91    11   GATA2;GFI1B;FOS;STAT5A;FOSB           0.055661  0.075040
# 86    12     GATA2;GFI1B;FOS;REL;MEF2C           0.050087  0.068441
#
#     reprog_to_hsc_1           recipe_diff
#                mean       std        mean       std
# 50         0.805842  0.067341    0.059285  0.078612
# 90         0.807415  0.068167    0.057449  0.079576
# 92         0.809019  0.069646    0.055576  0.081303
# 87         0.809166  0.066829    0.055405  0.078014
# 156        0.809359  0.068392    0.055179  0.079838
# 158        0.809630  0.069032    0.054863  0.080586
# 110        0.809914  0.069010    0.054531  0.080561
# 112        0.809995  0.069403    0.054437  0.081019
# 155        0.810024  0.069151    0.054403  0.080725
# 109        0.810464  0.069101    0.053889  0.080666
# 91         0.810989  0.068343    0.053277  0.079781
# 86         0.811197  0.070433    0.053034  0.082221

# %% [markdown]
# ## Results Dataframe: About

# %%
results_df['recipe'] = results_df['cluster_number'].apply(get_reprog_recipe_name)

# %%
results_df.columns
# Out:
# Index(['cluster_number', 'recipe_number', 'recipe', 'reprog_to_hsc_1',
#        'fib_1_to_reprog_10', 'recipe_diff'],
#       dtype='object')

# %%
# reorder with results_df but get the list from combined_df or whatever its called 

# Sort the DataFrame by recipe_diff in descending order
results_df = results_df.sort_values(by='recipe_diff', ascending=False).reset_index(drop=True)

# # Add a new rank column
# results_df.insert(0, 'rank', results_df.index + 1)

# Display the first few rows of the sorted DataFrame
results_df.head(10)
# Out:
#    cluster_number  recipe_number                       recipe  \
# 0             607             61    GATA2;FOS;STAT5A;REL;ETV6
# 1             676             68  GATA2;FOS;STAT5A;IKZF1;ETV6
# 2             595             60   GATA2;FOS;STAT5A;REL;MEF2C
# 3             774             78     GATA2;FOS;REL;IKZF1;ETV6
# 4             163             17  GATA2;GFI1B;FOS;IKZF1;MEF2C
# 5             810             81     GATA2;FOS;REL;MEF2C;ETV6
# 6             109             11     GATA2;GFI1B;FOS;REL;ETV6
# 7             206             21   GATA2;GFI1B;FOS;MEF2C;ETV6
# 8              96             10    GATA2;GFI1B;FOS;REL;MEF2C
# 9             180             18   GATA2;GFI1B;FOS;IKZF1;ETV6
#
#    reprog_to_hsc_1  fib_1_to_reprog_10  recipe_diff
# 0         0.678985            0.200316     0.207374
# 1         0.680233            0.186998     0.205917
# 2         0.681894            0.200065     0.203978
# 3         0.682960            0.191363     0.202733
# 4         0.683928            0.202149     0.201604
# 5         0.684013            0.197463     0.201505
# 6         0.684428            0.199118     0.201020
# 7         0.684440            0.192777     0.201006
# 8         0.684497            0.194818     0.200939
# 9         0.684521            0.200663     0.200911

# %%
# condensed_results.head(12)

# %%
# this cell needed to be lower to display the plots, couldnt tell ya why
results_df['recipe'] = results_df['cluster_number'].apply(get_reprog_recipe_name)
results_df
# Out:
#       cluster_number  recipe_number                       recipe  \
# 0                607             61    GATA2;FOS;STAT5A;REL;ETV6
# 1                676             68  GATA2;FOS;STAT5A;IKZF1;ETV6
# 2                595             60   GATA2;FOS;STAT5A;REL;MEF2C
# 3                774             78     GATA2;FOS;REL;IKZF1;ETV6
# 4                163             17  GATA2;GFI1B;FOS;IKZF1;MEF2C
# ...              ...            ...                          ...
# 2515            2498            250    REL;FOSB;RUNX3;MEF2C;ETV6
# 2516            2475            248    REL;FOSB;IKZF1;RUNX3;ETV6
# 2517            1942            195  GFI1B;FOSB;RUNX3;MEF2C;ETV6
# 2518            2476            248    REL;FOSB;IKZF1;RUNX3;ETV6
# 2519            1930            193  GFI1B;FOSB;IKZF1;RUNX3;ETV6
#
#       reprog_to_hsc_1  fib_1_to_reprog_10  recipe_diff
# 0            0.678985            0.200316     0.207374
# 1            0.680233            0.186998     0.205917
# 2            0.681894            0.200065     0.203978
# 3            0.682960            0.191363     0.202733
# 4            0.683928            0.202149     0.201604
# ...               ...                 ...          ...
# 2515         0.898876            0.006722    -0.049320
# 2516         0.899075            0.006540    -0.049552
# 2517         0.899168            0.009380    -0.049661
# 2518         0.899506            0.006830    -0.050055
# 2519         0.900260            0.006052    -0.050935
#
# [2520 rows x 6 columns]

# %%
inspecting_recipe_61 = results_df[results_df['recipe_number'] == 61]
inspecting_recipe_61.sort_values(by='recipe_diff')
inspecting_recipe_61.head(12)
# Out:
#       cluster_number  recipe_number                     recipe  \
# 0                607             61  GATA2;FOS;STAT5A;REL;ETV6
# 268              603             61  GATA2;FOS;STAT5A;REL;ETV6
# 566              610             61  GATA2;FOS;STAT5A;REL;ETV6
# 835              608             61  GATA2;FOS;STAT5A;REL;ETV6
# 1014             606             61  GATA2;FOS;STAT5A;REL;ETV6
# 1346             604             61  GATA2;FOS;STAT5A;REL;ETV6
# 1685             602             61  GATA2;FOS;STAT5A;REL;ETV6
# 1706             601             61  GATA2;FOS;STAT5A;REL;ETV6
# 2053             605             61  GATA2;FOS;STAT5A;REL;ETV6
# 2247             609             61  GATA2;FOS;STAT5A;REL;ETV6
#
#       reprog_to_hsc_1  fib_1_to_reprog_10  recipe_diff
# 0            0.678985            0.200316     0.207374
# 268          0.728933            0.119492     0.149066
# 566          0.752722            0.033000     0.121296
# 835          0.794572            0.006110     0.072442
# 1014         0.822893            0.064566     0.039380
# 1346         0.840303            0.008709     0.019056
# 1685         0.861516            0.025639    -0.005707
# 1706         0.862626            0.003120    -0.007002
# 2053         0.885258            0.005138    -0.033423
# 2247         0.892026            0.005559    -0.041324

# %%
# Now that I have ranked results_df, I want to filter out to only have to see the ten with the highest recipe_diff.  I'll just do this manually:

results_df['recipe'] = results_df['recipe'].astype(str)

highest_rdiff = ['GATA2;FOS;REL;IKZF1;MEF2C',
                'GATA2;GFI1B;FOS;STAT5A;ETV6',
                'GATA2;GFI1B;FOS;STAT5A;IKZF1', 
                'GATA2;GFI1B;FOS;REL;RUNX',
                'GATA2;STAT5A;REL;IKZF1;MEF2C',
                'GATA2;STAT5A;REL;MEF2C;ETV6',
                'GATA2;GFI1B;REL;IKZF1;MEF2C',
                'GATA2;GFI1B;REL;MEF2C;ETV6',
                'GATA2;STAT5A;REL;IKZF1;ETV6',
                'GATA2;GFI1B;REL;IKZF1;ETV6']

results_high_rdiff = results_df[results_df['recipe'].isin(highest_rdiff)]
list2 = results_high_rdiff['recipe'].unique()

# IMPORTANT NOTE: RIGHT NOW                'GATA2;GFI1B;FOS;REL;RUNX',     IS MISSING FROM THE DF!

# %%
# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt


# # Define updated custom colors
# colors = [
#     "#F5F5F5",  # Very Light Cream
#     "#F8E6D8",  # Light Warm Cream
#     "#F4A78A",  # Light Orange Clay
#     "#FF6F61",  # Coral
#     "#9FD3C7",  # Soft Mint Green
#     "#8CCB9B",  # Spring Green
#     "#A8C8E8",  # Muted Sky Blue
#     "#D0E6F0",  # Very Light Powder Blue
#     "#E6E6FA",  # Lavender
#     "#B39DDB",  # Purple
# ]

# # Ensure the number of colors matches the number of unique recipes
# unique_recipes = results_high_rdiff['recipe'].unique()
# if len(unique_recipes) > len(colors):
#     raise ValueError("Not enough colors specified for the number of unique recipes.")

# # Create a color mapping
# color_map = dict(zip(unique_recipes, colors))

# # Create the box plot
# plt.figure(figsize=(14, 8))
# box_plot = sns.boxplot(x='recipe', y='recipe_diff', data=results_high_rdiff, palette=color_map)

# # Rotate x-axis labels for better readability
# plt.xticks(rotation=30, ha='right')
# plt.title('Box Plot of Recipe Differences')
# plt.xlabel('Recipe')
# plt.ylabel('Recipe Difference')
# plt.tight_layout()  # Adjust layout to fit labels

# # Show the plot
# plt.show()

# %% [markdown]
# ## Recipe Diff (|fin-init| - |fin-mid|) / |fin-init|

# %%
# Adjusting condensed results for the re-ranking by mean

condensed_results = condensed_results.sort_values(by=('recipe_diff', 'mean'), ascending=False)
condensed_results[('rank', '')] = condensed_results[('recipe_diff', 'mean')].rank(ascending=False).astype(int)


# Reorder columns to place 'rank' on the left
condensed_results = condensed_results[[('rank', ''),
                                       ('recipe', ''),
                                       ('fib_1_to_reprog_10', 'mean'),
                                       ('fib_1_to_reprog_10', 'std'),
                                       ('reprog_to_hsc_1', 'mean'),
                                       ('reprog_to_hsc_1', 'std'),
                                       ('recipe_diff', 'mean'),
                                       ('recipe_diff', 'std')]]

#condensed_results[('rank','')].max()
condensed_results

# Adjusting results for filtering by these values

# %%
condensed_results['reprog_to_hsc_1'].max()

# %%
# add back the names of results column to results
results_df['recipe'] = results_df['cluster_number'].apply(get_reprog_recipe_name)
results_df

# %%
results_df.head(10)

# %%
results_df.to_csv('/nfs/turbo/umms-indikar/shared/projects/geneformer/fib15k/test812.csv')

# %%
results_df['recipe'].unique()

# %%
# Now that I have ranked results_df, I want to filter out to only have to see the ten with the highest recipe_diff.  I'll just do this manually:

results_df['recipe'] = results_df['recipe'].astype(str)

closest_to_target = condensed_results.loc[condensed_results['rank'].isin(range(1, 11)), 'recipe'].tolist()


results_close_target = results_df[results_df['recipe'].isin(highest_rdiff)]
list1 = results_close_target['recipe'].unique()
list1
# IMPORTANT NOTE: RIGHT NOW                'GATA2;GFI1B;FOS;REL;RUNX',     IS MISSING FROM THE DF!

# %%
are_equal = list1 == list2
are_equal

# %% [markdown]
# # Plotting

# %%
from collections import defaultdict

# Dictionary mapping variable columns to their descriptive plot titles
plot_titles = {
    'fib_1_to_reprog_10': "Box Plot of Recipes Furthest From Source",
    'reprog_to_hsc_1': "Box Plot of Recipes Closest to Target",
    'recipe_diff': "Box Plot of Recipe Differences"
}

def print_list_overlaps(recipe_lists):
    # Print recipes that appear in more than one loop with their ranks
    found = False
    for recipe, ranks in recipe_lists.items():
        if len(ranks) > 1:
            ranks_str = ", ".join([f"{stat}: rank {rank}" for stat, rank in ranks.items()])
            print(f"Recipe '{recipe}' appeared in multiple loops with the following ranks: {ranks_str}")
            found = True

    if not found:
        print("No recipes appeared in multiple loops.")


def create_plots(results_df, stats, colors, init_to_fin_dist, ascending_list, column='recipe_diff'):
    results_df['recipe_diff'] = (init_to_fin_dist - results_df['reprog_to_hsc_1']) / init_to_fin_dist
    recipe_lists = defaultdict(dict)
    
    if len(ascending_list) != len(stats):
        raise ValueError("The length of ascending_list must match the length of stats.")
    
    for i, stat in enumerate(stats):
        ascending = ascending_list[i]
        print(f"Processing statistic: {stat} with ascending={ascending}")
        
        condensed_results_toplot = results_df.groupby('recipe').agg({
            'fib_1_to_reprog_10': stat,
            'reprog_to_hsc_1': stat,
            'recipe_diff': stat
        }).reset_index()
        
        condensed_results_toplot['rank'] = condensed_results_toplot[column].rank(ascending=ascending).astype(int)
        
        top_recipes = condensed_results_toplot[condensed_results_toplot['rank'] <= 20]
        
        for recipe in top_recipes['recipe']:
            recipe_lists[recipe][stat] = top_recipes[top_recipes['recipe'] == recipe]['rank'].values[0]
    
    overlapping_recipes = {recipe for recipe, ranks in recipe_lists.items() if len(ranks) > 1}
    non_gray_colors = colors[1:]
    num_colors = len(non_gray_colors)
    color_map = {recipe: non_gray_colors[i % num_colors] for i, recipe in enumerate(overlapping_recipes)}
    color_map.update({recipe: "#E4F1F9" for recipe in results_df['recipe'].unique() if recipe not in overlapping_recipes})
    
    fig, axes = plt.subplots(2, 1, figsize=(14, 16))

    for i, stat in enumerate(stats):
        ascending = ascending_list[i]
        print(f"Creating plot for statistic: {stat} with ascending={ascending}")
        
        condensed_results_toplot = results_df.groupby('recipe').agg({
            'fib_1_to_reprog_10': stat,
            'reprog_to_hsc_1': stat,
            'recipe_diff': stat
        }).reset_index()
        
        condensed_results_toplot['rank'] = condensed_results_toplot[column].rank(ascending=ascending).astype(int)
        
        top_recipes = condensed_results_toplot[condensed_results_toplot['rank'] <= 20]
        sorted_recipes = top_recipes.sort_values(by='rank')['recipe']
        
        plotting_results_df = results_df[results_df['recipe'].isin(sorted_recipes)]

        ax = axes[i]
        sns.boxplot(x='recipe', y=column, data=plotting_results_df, palette=color_map, 
                    order=sorted_recipes, ax=ax)
        
        ax.set_xlabel('')
        ax.set_ylabel(f"{plot_titles[column]} ({stat.capitalize()})", fontsize=16)
        ax.set_xticklabels(ax.get_xticklabels(), rotation=(30 if i == 0 else -30), ha='left')

        if i == 0:
            ax.xaxis.set_ticks_position('top')
            ax.xaxis.set_label_position('top')
            ax.xaxis.tick_top()

    plt.tight_layout()
    plt.show()

    return recipe_lists


# Example usage
init_to_fin_dist = 0.85662723
colors =  [
    "#2C3E50",  # Storm Gray (Neutral)
    "#FFFDD0",  # Cream
    "#FA8072",  # Salmon Pink
    "#9FD3C7",  # Soft Mint Green
    "#F4A78A",  # Light Orange Clay
    "#FF6F61",  # Coral
    "#A8C8E8",  # Muted Sky Blue
    "#D0E6F0",  # Very Light Powder Blue
    "#E6E6FA",  # Lavender
    "#B39DDB",  # Purple
]

# Assuming `colors` list is used in the `create_plots` function as the `colors` argument

stats_rdiff = ['mean', 'max']
stats_closest = ['mean', 'min']
ascending_rdiff = [False, False]  # For 'mean' and 'max', ranking higher values first
ascending_closest = [False, True]  # For 'mean' and 'min', ranking lower values first

# Pass the ascending lists corresponding to each stats list
recipe_list_rdiff = create_plots(results_df, stats_rdiff, colors, init_to_fin_dist, ascending_rdiff, 'recipe_diff')
print_list_overlaps(recipe_list_rdiff)

recipe_list_closest = create_plots(results_df, stats_closest, colors, init_to_fin_dist, ascending_closest, 'reprog_to_hsc_1')
print_list_overlaps(recipe_list_closest)

# %%
# Function to print the top recipes with a label indicating the plot
def print_top_recipes(recipe_lists, plot_label):
    print(f"\nTop Recipes for {plot_label}:")
    for recipe, ranks in recipe_lists.items():
        print(f"Recipe: {recipe}, Ranks: {ranks}")

# Run the original plots and print the top recipes
recipe_list_rdiff = create_plots(results_df, stats_rdiff, colors, init_to_fin_dist, ascending_rdiff, 'recipe_diff')
print_top_recipes(recipe_list_rdiff, "Box Plot of Recipe Differences")

recipe_list_closest = create_plots(results_df, stats_closest, colors, init_to_fin_dist, ascending_closest, 'reprog_to_hsc_1')
print_top_recipes(recipe_list_closest, "Box Plot of Recipes Closest to Target")

# %%
def print_top_recipes(recipe_lists, plot_label):
    print(f"\nTop Recipes for {plot_label}:")
    all_stats = set()
    for ranks in recipe_lists.values():
        all_stats.update(ranks.keys())
    
    for stat in sorted(all_stats):
        print(f"\nRanked by {stat}:")
        sorted_recipes = sorted(recipe_lists.items(), key=lambda x: x[1].get(stat, float('inf')))
        for recipe, ranks in sorted_recipes:
            rank = ranks.get(stat, 'N/A')
            print(f"Recipe: {recipe}, Rank: {rank}")

# Run the original plots and print the top recipes in order of their rank
recipe_list_rdiff = create_plots(results_df, stats_rdiff, colors, init_to_fin_dist, ascending_rdiff, 'recipe_diff')
print_top_recipes(recipe_list_rdiff, "Box Plot of Recipe Differences")

recipe_list_closest = create_plots(results_df, stats_closest, colors, init_to_fin_dist, ascending_closest, 'reprog_to_hsc_1')
print_top_recipes(recipe_list_closest, "Box Plot of Recipes Closest to Target")
