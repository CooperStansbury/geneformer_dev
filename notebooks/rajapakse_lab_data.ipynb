# %%
import pandas as pd
import scanpy as sc

# %%
fpath = "/nfs/turbo/umms-indikar/shared/projects/geneformer/data/rajapakse_lab_data_jpic.h5ad"

adata = sc.read_h5ad(fpath)
adata
# Out:
# AnnData object with n_obs × n_vars = 66 × 19393
#     obs: 'dataset', 'sample_id', 'timepoint', 'hour', 'n_counts', 'control', 'order', 'replicate', 'batch'
#     var: 'gene_id', 'token_id', 'Chromosome', 'Source', 'Feature', 'Start', 'End', 'Score', 'Strand', 'Frame', 'gene_version', 'gene_source', 'gene_biotype', 'transcript_id', 'transcript_version', 'transcript_name', 'transcript_source', 'transcript_biotype', 'tag', 'ccds_id', 'exon_number', 'exon_id', 'exon_version', 'protein_id', 'protein_version', 'transcript_support_level', 'ensembl_id'

# %%
adata.obs.head()
# Out:
# gene_name    A1BG  A1CF   A2M  A2ML1  A3GALT2  A4GALT  A4GNT  AAAS  AACS  \
# data_id
# S1a            12     0     0      0        0     150      0   330   473
# S1b             5     0     0      0        0     133      0   342   464
# S2a             5     0     0      0        0     122      0   507   565
# S2b             9     0     2      0        0     137      0   563   519
# S3a             2     0     0      0        0     143      0   535   481
# ...           ...   ...   ...    ...      ...     ...    ...   ...   ...
# 63275_T11R3    14     3  3461      0        0     515      4   439   777
# 63290_T12R3    14     0  2359      0        2     344      9   226   453
# 63287_T13R3     8     5  2805      0        3     780      2   368   688
# 63284_T14R3    14     0  3002      1        1     429      9   246   526
# 63293_T15R3    11     1  3481      0        0     462      6   251   412
#
# gene_name    AADAC  ...  ZWILCH  ZWINT  ZXDA  ZXDB  ZXDC  ZYG11A  ZYG11B  \
# data_id             ...
# S1a              0  ...     299    710    50   164   287     283     257
# S1b              0  ...     309    705    48   176   312     293     315
# S2a              0  ...     747   2497    33   125   286     432     383
# S2b              0  ...     838   2632    31   157   361     458     353
# S3a              0  ...     747   1767    48   152   338     588     432
# ...            ...  ...     ...    ...   ...   ...   ...     ...     ...
# 63275_T11R3      0  ...     385    305   134   305   589      15    1599
# 63290_T12R3      0  ...     191    200    47   137   210      15     751
# 63287_T13R3      0  ...     200    162    85   259   512      23    1518
# 63284_T14R3      0  ...     208    230    69   157   240      21     892
# 63293_T15R3      0  ...     260    238   137   309   402      11    1158
#
# gene_name     ZYX  ZZEF1  ZZZ3
# data_id
# S1a           636    913   450
# S1b           675    946   470
# S2a           921   1175   674
# S2b           922   1242   696
# S3a           779   1074   743
# ...           ...    ...   ...
# 63275_T11R3  2245   1174  1629
# 63290_T12R3  2212    827   706
# 63287_T13R3  1973   1285  1847
# 63284_T14R3  2657    870   810
# 63293_T15R3  3806   1229  1352
#
# [66 rows x 19393 columns]

# %%
break
# Out:
#   Cell In[3], line 1
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
sc.tl.pca(adata)
sc.pp.neighbors(adata)
sc.tl.umap(adata)
sc.tl.leiden(adata, resolution=1)
# Out:
# /tmp/ipykernel_1745928/3962055571.py:4: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution=1)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 6
#       3 sc.tl.umap(adata)
#       4 sc.tl.leiden(adata, resolution=1)
# ----> 6 plt.rcParams['figure.dpi'] = 200
#       7 plt.rcParams['figure.figsize'] = 12, 3
#       9 sns.barplot(x=adata.obs_names.astype(int),
#      10             y=adata.obs['leiden'].astype(int) + 1,
#      11             hue=adata.obs['leiden'].astype(int) + 1,
#      12             palette='viridis',
#      13             )
#
# NameError: name 'plt' is not defined

# %%
# plt.rcParams['figure.dpi'] = 200
# plt.rcParams['figure.figsize'] = 12, 3

sc.pl.umap(adata, 
           color=['dataset'])

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 66 × 19393
#     obs: 'dataset', 'sample_id', 'timepoint', 'hour', 'n_counts', 'control', 'order', 'replicate', 'batch', 'leiden'
#     var: 'gene_id', 'token_id', 'Chromosome', 'Source', 'Feature', 'Start', 'End', 'Score', 'Strand', 'Frame', 'gene_version', 'gene_source', 'gene_biotype', 'transcript_id', 'transcript_version', 'transcript_name', 'transcript_source', 'transcript_biotype', 'tag', 'ccds_id', 'exon_number', 'exon_id', 'exon_version', 'protein_id', 'protein_version', 'transcript_support_level', 'ensembl_id'
#     uns: 'pca', 'neighbors', 'umap', 'leiden', 'dataset_colors'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'
